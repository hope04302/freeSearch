# %% [markdown]
# <a href="https://colab.research.google.com/github/hope04302/freeSearch/blob/main/commonAI/ChatGPT35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5월 17일

# %%
# %%bash
# pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 13.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 실험 1
# 긍정적인 말을 0, 부정적인 말을 1로 (우찬이 아이디어)
#
# > **결과**:
# >
# > 0 또는 1로 대답하거나, 그러지 않는 경우 모두 존재
#
# > **이견**: 부정적인 말과 악플을 동치로 둘 수 있냐
# >
# > 예를 들어, '개인적으로 ~~한 부분은 아쉽네요'라는 말이 부정적임에는 틀림없지만, 악플이라고는 할 수 없음
#
# > **이견 2**: 부정적인 말, 긍정적인 말 외에 중립적인 말도 따로 두어야 되지 않나?
# >
# > 많은 논문 및 데이터셋에서 댓글의 정도를 세 단계로 표현

# %%
import openai

openai.api_key = "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"

messages = []

user_content = '지금부터 부정적인 말이면 0, 긍정적인 말이면 1이라고 대답해'
messages.append({"role": "user", "content": user_content})
completion = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=messages)
assistant_content = completion.choices[0].message["content"].strip()
messages.append({"role": "assistant", "content": f"{assistant_content}"})

while True:
    user_content = input("user : ")
    if not user_content:
        break
    messages.append({"role": "user", "content": f"{user_content}"})
    try:
        completion = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=messages)
    except Exception as e:
        print(e)
        break
    assistant_content = completion.choices[0].message["content"].strip()
    messages.append({"role": "assistant", "content": f"{assistant_content}"})
    print(f"GPT : {assistant_content}")
# Out:
# user : nigger
# GPT : 제한된 언어 사용으로 인하여 이 질문에 대한 답변을 드릴 수 없습니다. 제한되지 않은 언어를 사용해주세요.
# user : 니거
# GPT : 제한된 언어 사용으로 인하여 이 질문에 대한 답변을 드릴 수 없습니다. 제한되지 않은 언어를 사용해주세요.
# user : 아니 뭘 하라고 씨발
# GPT : 저는 공손한 대화만 가능합니다. 상호 존중과 예의를 지켜주세요. 부적절한 언어는 사용하지 않도록 하겠습니다. 원하시는 질문이 있다면, 다시 문의해주세요.
# user : 느금
# Rate limit reached for default-gpt-3.5-turbo in organization org-3i6fBqi4eVx6ZQWT17OhhDge on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.

# %% [markdown]
# ## 실험 2
# 긍정적인 말을 0, 중립을 1, 긍정적인 말을 2로 표현하게 함
#
# > **결과**:
# >
# > 제대로 된 대답이 되지 않음(망함).

# %%
import openai

openai.api_key = "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"

messages = []

user_content = '지금부터 부정적인 말이면 0, 중립적인 말이면 1, 긍정적인 말이면 2라고 대답해'
messages.append({"role": "user", "content": user_content})
completion = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=messages)
assistant_content = completion.choices[0].message["content"].strip()
messages.append({"role": "assistant", "content": f"{assistant_content}"})

while True:
    user_content = input("user : ")
    if not user_content:
        break
    messages.append({"role": "user", "content": f"{user_content}"})
    try:
        completion = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=messages)
    except Exception as e:
        print(e)
        break
    assistant_content = completion.choices[0].message["content"].strip()
    messages.append({"role": "assistant", "content": f"{assistant_content}"})
    print(f"GPT : {assistant_content}")
# Out:
# user : 느금
# Rate limit reached for default-gpt-3.5-turbo in organization org-3i6fBqi4eVx6ZQWT17OhhDge on requests per min. Limit: 3 / min. Please try again in 20s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.

# %% [markdown]
# ## 실험 3
# 아래 그림에서 '혐오표현 클래스'에 따라 질문 입력 (주원이 아이디어)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import openai

openai.api_key = "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"

messages = []

user_content = """지금부터 모욕성이나 공격성이 존재하지 않으면 0,
대상을 심하게 비난하거나 깎아내려서 정신적인 고통 등을 야기할 수 있는 표현은 1,
모욕이나 혐오에는 미치지 않지만 공격적이고 무례한 내용을 2로 표현해줘"""

messages.append({"role": "user", "content": user_content})
completion = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=messages)
assistant_content = completion.choices[0].message["content"].strip()
messages.append({"role": "assistant", "content": f"{assistant_content}"})

while True:
    user_content = input("user : ")
    if not user_content:
        break
    messages.append({"role": "user", "content": f"{user_content}"})
    try:
        completion = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=messages)
    except Exception as e:
        print(e)
        break
    assistant_content = completion.choices[0].message["content"].strip()
    messages.append({"role": "assistant", "content": f"{assistant_content}"})
    print(f"GPT : {assistant_content}")
# Out:
# GPT : 죄송합니다, 저도 모르는 표현이네요. 다른 질문이 있으시면 언제든지 물어보세요!
# GPT : 또 다른 질문이 있으면 언제든지 물어보세요! 저는 당신을 도와드릴 준비가 되어 있습니다.
